# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16
block_size = 32 # context_length
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)


with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string
# implemented a character encoding
# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

#  bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):

            idx_cond = idx[:, -block_size:]

            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            probs = F.softmax(logits, dim=-1) # (B, C)
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# creating a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6568, val loss 2.6670
# step 200: train loss 2.5091, val loss 2.5059
# step 300: train loss 2.4197, val loss 2.4337
# step 400: train loss 2.3503, val loss 2.3566
# step 500: train loss 2.2965, val loss 2.3130
# step 600: train loss 2.2416, val loss 2.2509
# step 700: train loss 2.2056, val loss 2.2189
# step 800: train loss 2.1641, val loss 2.1877
# step 900: train loss 2.1239, val loss 2.1502
# step 1000: train loss 2.1035, val loss 2.1308
# step 1100: train loss 2.0695, val loss 2.1185
# step 1200: train loss 2.0390, val loss 2.0807
# step 1300: train loss 2.0245, val loss 2.0640
# step 1400: train loss 1.9935, val loss 2.0376
# step 1500: train loss 1.9702, val loss 2.0296
# step 1600: train loss 1.9599, val loss 2.0445
# step 1700: train loss 1.9430, val loss 2.0147
# step 1800: train loss 1.9090, val loss 1.9956
# step 1900: train loss 1.9098, val loss 1.9895
# step 2000: train loss 1.8848, val loss 1.9949
# step 2100: train loss 1.8710, val loss 1.9751
# step 2200: train loss 1.8595, val loss 1.9619
# step 2300: train loss 1.8558, val loss 1.9538
# step 2400: train loss 1.8401, val loss 1.9408
# step 2500: train loss 1.8162, val loss 1.9403
# step 2600: train loss 1.8259, val loss 1.9369
# step 2700: train loss 1.8121, val loss 1.9324
# step 2800: train loss 1.8078, val loss 1.9239
# step 2900: train loss 1.8043, val loss 1.9308
# step 3000: train loss 1.7971, val loss 1.9247
# step 3100: train loss 1.7703, val loss 1.9189
# step 3200: train loss 1.7560, val loss 1.9132
# step 3300: train loss 1.7553, val loss 1.9049
# step 3400: train loss 1.7567, val loss 1.8987
# step 3500: train loss 1.7398, val loss 1.8967
# step 3600: train loss 1.7261, val loss 1.8888
# step 3700: train loss 1.7289, val loss 1.8851
# step 3800: train loss 1.7213, val loss 1.8981
# step 3900: train loss 1.7226, val loss 1.8777
# step 4000: train loss 1.7136, val loss 1.8627
# step 4100: train loss 1.7130, val loss 1.8744
# step 4200: train loss 1.7050, val loss 1.8698
# step 4300: train loss 1.6968, val loss 1.8499
# step 4400: train loss 1.7060, val loss 1.8674
# step 4500: train loss 1.6906, val loss 1.8553
# step 4600: train loss 1.6876, val loss 1.8365
# step 4700: train loss 1.6827, val loss 1.8464
# step 4800: train loss 1.6671, val loss 1.8483
# step 4900: train loss 1.6675, val loss 1.8406
# step 5000: train loss 1.6630, val loss 1.8248
# step 5100: train loss 1.6691, val loss 1.8348
# step 5200: train loss 1.6573, val loss 1.8217
# step 5300: train loss 1.6631, val loss 1.8238
# step 5400: train loss 1.6555, val loss 1.8213
# step 5500: train loss 1.6506, val loss 1.8041
# step 5600: train loss 1.6570, val loss 1.8210
# step 5700: train loss 1.6534, val loss 1.8169
# step 5800: train loss 1.6399, val loss 1.8127
# step 5900: train loss 1.6441, val loss 1.8128
# step 6000: train loss 1.6384, val loss 1.8041
# step 6100: train loss 1.6386, val loss 1.7952
# step 6200: train loss 1.6433, val loss 1.7876
# step 6300: train loss 1.6285, val loss 1.7996
# step 6400: train loss 1.6265, val loss 1.8029
# step 6500: train loss 1.6230, val loss 1.7866
# step 6600: train loss 1.6220, val loss 1.7821
# step 6700: train loss 1.6207, val loss 1.7967
# step 6800: train loss 1.6231, val loss 1.7993
# step 6900: train loss 1.6141, val loss 1.7861
# step 7000: train loss 1.6119, val loss 1.7860
# step 7100: train loss 1.6196, val loss 1.7887
# step 7200: train loss 1.6116, val loss 1.7994
# step 7300: train loss 1.6097, val loss 1.7731
# step 7400: train loss 1.6109, val loss 1.7854
# step 7500: train loss 1.5949, val loss 1.7881
# step 7600: train loss 1.6025, val loss 1.7851
# step 7700: train loss 1.5906, val loss 1.7731
# step 7800: train loss 1.6060, val loss 1.7703
# step 7900: train loss 1.6007, val loss 1.7729
# step 8000: train loss 1.5957, val loss 1.7770
# step 8100: train loss 1.5986, val loss 1.7817
# step 8200: train loss 1.6023, val loss 1.7926
# step 8300: train loss 1.5916, val loss 1.7642
# step 8400: train loss 1.5944, val loss 1.7766
# step 8500: train loss 1.5919, val loss 1.7686
# step 8600: train loss 1.5912, val loss 1.7804
# step 8700: train loss 1.5831, val loss 1.7706
# step 8800: train loss 1.5718, val loss 1.7719
# step 8900: train loss 1.5854, val loss 1.7524
# step 9000: train loss 1.5810, val loss 1.7623
# step 9100: train loss 1.5704, val loss 1.7517
# step 9200: train loss 1.5894, val loss 1.7653
# step 9300: train loss 1.5737, val loss 1.7460
# step 9400: train loss 1.5748, val loss 1.7425
# step 9500: train loss 1.5771, val loss 1.7656
# step 9600: train loss 1.5734, val loss 1.7532
# step 9700: train loss 1.5732, val loss 1.7420
# step 9800: train loss 1.5596, val loss 1.7594
# step 9900: train loss 1.5717, val loss 1.7477
# step 9999: train loss 1.5625, val loss 1.7434
#
#
# SOMEN:
# Blish far conjurel, it all is before, with you nest.
#
# KING HENRY Zain:
# A enemirish is, day them sham: whe the shead,
# And lound misery me banino lord! god, a ligeter.
#
# BENVOLIO:
# Who more have please ply. All I'll be Making from yours
# Madlets, the perced reporal no mother and bencention indeed
# Mercunal. Contural, 'tis need.
# What, or in use in this far
# shall gall reliege: yet he I conver-nighed! where doead,
# Call I prest of to-morrive all.
# 'Tis read, yourselver to rightlem,
# Making wanligits, quake to well, gaile's her rance your gleits,
# Here of part is my litters old his fressed into cun
# hoad intel's bother priude our grace:
# How thou in of the cdreas.
# But from Bod thy pics.
#
# CORIOLANUS:
# Berior mine ghard haty them, I, go notless.
#
# CLAUDINE:
# Fare you: and let here and his! come; fellow the kneel.
#
# Come:
# Mether man indeeding, Freputher's thou here;
#
# MONTANGELO:
# He hath decase him wont;
# Which in from my lord! Clifford, I do inchild and come;
# And as voice 'em. Lance blood by dear.
#
# Andthors:
# I would be a were ompenquirel weep.
#
# BOVOLIO:
# O for here ho, sight; bow the sweet toged in,
# When by this I neith and have know it,
# her did indmile recond you remazen young, we ill thou deting to comesehat,
# Our come bear a gurtes and report,
# Why but we kir curse you; I have nus lord.
#
# EDWARD:
# So have attend! I'll would presents,
# This wife come. Encus, sir, and damt me?--O, thrights whom a disliging,
# With that is herself! and for it calle parlans! tower their;
# Brathes, they blood and thread than sligienst, mother our cable here; if his brought havil: that us. Shall not her perperalious,
# Marrise, belike sight. To promiod.
#
# QUEEN IVO:
# A, a man'streals, that was their, I sick;
# Parcute you for here poor thine, my dear
# enemied the fare; but are was in life, whents
# Of yet will all
# this way none zerself, and my fathers? bear, would from sleaping Mercupdens
# We pring nurse kill, they Raking, sir, a pund peen, to lady and joy.
#
# KING RICHERDicy:
# Hath sounder power lawful king one
# And is. ye
